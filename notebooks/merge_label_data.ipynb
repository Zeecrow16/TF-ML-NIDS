# %%
import pandas as pd

# %%
df_cwt = pd.read_csv("cwt_binary_label.csv")
df_unsw = pd.read_csv("../data/NF-UNSW-NB15-v3.csv")

# %%
df_unsw['flow_id'] = df_unsw.index

# %%
get_temporal = [
    "FLOW_DURATION_MILLISECONDS",
    "SRC_TO_DST_IAT_MIN",
    "SRC_TO_DST_IAT_MAX",
    "SRC_TO_DST_IAT_AVG",
    "SRC_TO_DST_IAT_STDDEV", 
    "DST_TO_SRC_IAT_MIN",
    "DST_TO_SRC_IAT_MAX",
    "DST_TO_SRC_IAT_AVG",
    "DST_TO_SRC_IAT_STDDEV",
    "flow_id"
]

# %%
df_temporal = df_unsw[get_temporal]

# %%
df_merged = pd.merge(df_cwt, df_temporal, on="flow_id", how="inner")

# %%
print(df_merged.head())
# Out:
#    label  flow_id  cwt_scale_0  cwt_scale_1  cwt_scale_2  cwt_scale_3  \
# 0      1   366645     0.026187     0.131546     0.246531     0.531713
# 1      0  1170943     0.023581     0.305857     0.328660     0.580817
# 2      0   542038     0.023344     0.314943     0.322206     0.575210
# 3      0   540480     0.024536     0.268924     0.330943     0.597990
# 4      0   817994     0.024392     0.234902     0.318332     0.600377
#
#    cwt_scale_4  cwt_scale_5  cwt_scale_6  cwt_scale_7  ...  cwt_scale_126  \
# 0     0.392564     0.239554     0.223322     0.261458  ...       0.060804
# 1     0.411046     0.215342     0.082396     0.011906  ...       0.064356
# 2     0.407437     0.214143     0.083256     0.013400  ...       0.066328
# 3     0.430702     0.230303     0.092187     0.013262  ...       0.061387
# 4     0.427567     0.215873     0.076700     0.053621  ...       0.063881
#
#    FLOW_DURATION_MILLISECONDS  SRC_TO_DST_IAT_MIN  SRC_TO_DST_IAT_MAX  \
# 0                         235                   0                  74
# 1                         514                   0                 142
# 2                         849                   0                 270
# 3                         162                   0                   8
# 4                         836                   0                 187
#
#    SRC_TO_DST_IAT_AVG  SRC_TO_DST_IAT_STDDEV  DST_TO_SRC_IAT_MIN  \
# 0                  26                     29                   0
# 1                   9                     26                   0
# 2                  16                     47                   0
# 3                   1                      2                   0
# 4                  34                     56                   0
#
#    DST_TO_SRC_IAT_MAX  DST_TO_SRC_IAT_AVG  DST_TO_SRC_IAT_STDDEV
# 0                 174                  45                     67
# 1                 143                  12                     30
# 2                 279                  15                     53
# 3                   8                   1                      2
# 4                 228                  36                     61
#
# [5 rows x 138 columns]

# %%
df_merged.to_csv("../data/ml_binary_data.csv", index=False)
